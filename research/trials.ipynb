# %%
import gdown

# %%
url ="https://drive.google.com/file/d/1z0ecV0bgcxostwbnxSkYryNAcAG_PwzQ/view?usp=drive_link"

# %%
file_id=url.split('/')[-2]

# %%
prefix = "https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id,"CT_scan_dataset.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1z0ecV0bgcxostwbnxSkYryNAcAG_PwzQ
# From (redirected): https://drive.google.com/uc?id=1z0ecV0bgcxostwbnxSkYryNAcAG_PwzQ&confirm=t&uuid=85da193c-f066-4d4a-abba-7a1da443dc75
# To: c:\Users\Dell User\Desktop\DeepLearm\Deep_Learning\research\CT_scan_dataset.zip
# 100%|██████████| 1.63G/1.63G [03:59<00:00, 6.81MB/s]
# 'CT_scan_dataset.zip'
